# %% [markdown]
# Петухова Ксения БКЛ182

# %%
import pandas as pd
import RAKE
import nltk
from pymorphy2 import MorphAnalyzer
from pymorphy2.tokenizers import simple_word_tokenize
from nltk.corpus import stopwords
from summa import keywords
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import re
from nltk import word_tokenize, sent_tokenize 
from nltk.util import ngrams
# nltk.download('stopwords')
stop = stopwords.words('russian')
m = MorphAnalyzer()

# %% [markdown]
# ### Задание 1.

# %% [markdown]
# Собранный мною корпус состоит из текстов новостей The Village (https://www.the-village.ru). В качестве ключевых слов были взяты "теги", которые прописаны в конце каждой новости.

# %%
corpus = pd.read_csv("the_village.csv", sep=";")

# %% [markdown]
# В столбце "Village_keywords" - теги с сайта, в столбце "My_keywords" - ключевые слова, размеченные мной

# %%
corpus
# Out:
#                                                 Text  \
# 0  С 11 по 13 сентября в Гостином дворе пройдет у...
# 1  ЦВЗ «Манеж» запустил выставочный проект «33 зн...
# 2  Исследовательский центр имени Гамалеи при подд...
# 3  Рыбный ресторан «Охотка» открылся в конце июня...
# 4  Владельцы ТРК «Европолис» — Fort Group — подал...
# 5  Банк «Русский стандарт» изучил, что россияне п...
# 6  В Госдуму внесли законопроект о запуске механи...
# 7  Несмотря на возобновление авиасообщения с авгу...
# 8  Бренд московских сувениров Heart of Moscow вып...
# 9  Мэра Москвы Сергея Собянина не стали штрафоват...
#
#                                     Village_keywords  \
# 0  современное искусство, выставка, ярмарка, сosm...
# 1  выставки, уличное искусство, уличные выставки,...
# 2  коронавирус, вакцинация, вакцина, covid-19, се...
# 3  архитектура, сохранение исторического центра, ...
# 4  бизнес, суд, чиновники, ограничения, торговый ...
# 5  онлайн-шопинг, торговля, ритейл, деньги, интер...
# 6  вклады, покупка жилья, кредиты, ипотека, закон...
# 7  авиасообщение, авиасообщение с турцией, отмена...
# 8  значки, сказки, картины, художники, heart of m...
# 9  кофемания, масочный режим, карантин, штраф, се...
#
#                                          My_keywords
# 0  ярмарка, современное искусство, cosmoscow, сен...
# 1  манеж, выставочный проект, 33 знака, кириллица...
# 2  москва, вакцина, коронавирус, сергей собянин, ...
# 3  охотка, маросейка, уничтожение окон, историчес...
# 4  трк Европолис, fort group, суд, смольный, рабо...
# 5  мужчины, онлайн-магазины, женщины, товары для ...
# 6  вклад, покупка жилья, госдума, законопроект, и...
# 7  аэрофлот, отмена рейсов, август, закрытые границы
# 8                    значки, сказки, heart of moscow
# 9  собянин, маска, мэр москвы, сергей собянин, на...

# %% [markdown]
# ### Задание 2.

# %% [markdown]
# В качестве эталонной разметки возьмем пересечение разметки the village и моей разметки

# %%
def intersection():
    gold_kw = []
    village_keywords = list(corpus.Village_keywords)
    my_keywords = list(corpus.My_keywords)
    for i in range(len(my_keywords)): 
        gold_kw_per_text = []
        list_my_keywords = my_keywords[i].split(', ')
        list_v_keywords = village_keywords[i].split(', ')
        for keyword in list_my_keywords:
            if keyword in list_v_keywords:
                gold_kw_per_text.append(keyword)
        gold_kw.append(gold_kw_per_text)
        
    corpus['Gold'] = gold_kw
    return gold_kw

# %%
gold_kw = intersection()

# %% [markdown]
# На первый взгляд кажется, что разметка не сильно пересекается, но этому у меня есть 2 объяснения:
#
# 1) И у меня, и у The Village, ключевых слов достаточно мало;
#
# 2) Некоторые теги The Village не встречаются в тексте;

# %%
corpus
# Out:
#                                                 Text  \
# 0  С 11 по 13 сентября в Гостином дворе пройдет у...
# 1  ЦВЗ «Манеж» запустил выставочный проект «33 зн...
# 2  Исследовательский центр имени Гамалеи при подд...
# 3  Рыбный ресторан «Охотка» открылся в конце июня...
# 4  Владельцы ТРК «Европолис» — Fort Group — подал...
# 5  Банк «Русский стандарт» изучил, что россияне п...
# 6  В Госдуму внесли законопроект о запуске механи...
# 7  Несмотря на возобновление авиасообщения с авгу...
# 8  Бренд московских сувениров Heart of Moscow вып...
# 9  Мэра Москвы Сергея Собянина не стали штрафоват...
#
#                                     Village_keywords  \
# 0  современное искусство, выставка, ярмарка, сosm...
# 1  выставки, уличное искусство, уличные выставки,...
# 2  коронавирус, вакцинация, вакцина, covid-19, се...
# 3  архитектура, сохранение исторического центра, ...
# 4  бизнес, суд, чиновники, ограничения, торговый ...
# 5  онлайн-шопинг, торговля, ритейл, деньги, интер...
# 6  вклады, покупка жилья, кредиты, ипотека, закон...
# 7  авиасообщение, авиасообщение с турцией, отмена...
# 8  значки, сказки, картины, художники, heart of m...
# 9  кофемания, масочный режим, карантин, штраф, се...
#
#                                          My_keywords  \
# 0  ярмарка, современное искусство, cosmoscow, сен...
# 1  манеж, выставочный проект, 33 знака, кириллица...
# 2  москва, вакцина, коронавирус, сергей собянин, ...
# 3  охотка, маросейка, уничтожение окон, историчес...
# 4  трк Европолис, fort group, суд, смольный, рабо...
# 5  мужчины, онлайн-магазины, женщины, товары для ...
# 6  вклад, покупка жилья, госдума, законопроект, и...
# 7  аэрофлот, отмена рейсов, август, закрытые границы
# 8                    значки, сказки, heart of moscow
# 9  собянин, маска, мэр москвы, сергей собянин, на...
#
#                                                 Gold
# 0    [ярмарка, современное искусство, гостиный двор]
# 1                        [манеж, кириллица, алфавит]
# 2  [вакцина, коронавирус, сергей собянин, вакцина...
# 3                                [охотка, маросейка]
# 4                                 [суд, ограничения]
# 5                             [исследование, деньги]
# 6             [покупка жилья, госдума, законопроект]
# 7                          [аэрофлот, отмена рейсов]
# 8                  [значки, сказки, heart of moscow]
# 9  [сергей собянин, масочный режим, кофемания, ка...

# %% [markdown]
# ### Задание 3.

# %% [markdown]
# #### RAKE

# %%
def normalize_text(text):
    lemmas = []
    for t in simple_word_tokenize(text):
        lemmas.append(
            m.parse(t)[0].normal_form
        )
    return ' '.join(lemmas)

# %%
def rake_kw():
    kw_rake = []
    rake = RAKE.Rake(stop)
    for text in list(corpus.Text):
        kw_per_text = []
        kw_list = rake.run(normalize_text(text), maxWords=2, minFrequency=1)
        for l in kw_list:
            kw_per_text.append(l[0])
        kw_rake.append(kw_per_text)
        
    corpus['RAKE'] = kw_rake
    return kw_rake

# %%
kw_rake = rake_kw()

# %%
corpus
# Out:
#                                                 Text  \
# 0  С 11 по 13 сентября в Гостином дворе пройдет у...
# 1  ЦВЗ «Манеж» запустил выставочный проект «33 зн...
# 2  Исследовательский центр имени Гамалеи при подд...
# 3  Рыбный ресторан «Охотка» открылся в конце июня...
# 4  Владельцы ТРК «Европолис» — Fort Group — подал...
# 5  Банк «Русский стандарт» изучил, что россияне п...
# 6  В Госдуму внесли законопроект о запуске механи...
# 7  Несмотря на возобновление авиасообщения с авгу...
# 8  Бренд московских сувениров Heart of Moscow вып...
# 9  Мэра Москвы Сергея Собянина не стали штрафоват...
#
#                                     Village_keywords  \
# 0  современное искусство, выставка, ярмарка, сosm...
# 1  выставки, уличное искусство, уличные выставки,...
# 2  коронавирус, вакцинация, вакцина, covid-19, се...
# 3  архитектура, сохранение исторического центра, ...
# 4  бизнес, суд, чиновники, ограничения, торговый ...
# 5  онлайн-шопинг, торговля, ритейл, деньги, интер...
# 6  вклады, покупка жилья, кредиты, ипотека, закон...
# 7  авиасообщение, авиасообщение с турцией, отмена...
# 8  значки, сказки, картины, художники, heart of m...
# 9  кофемания, масочный режим, карантин, штраф, се...
#
#                                          My_keywords  \
# 0  ярмарка, современное искусство, cosmoscow, сен...
# 1  манеж, выставочный проект, 33 знака, кириллица...
# 2  москва, вакцина, коронавирус, сергей собянин, ...
# 3  охотка, маросейка, уничтожение окон, историчес...
# 4  трк Европолис, fort group, суд, смольный, рабо...
# 5  мужчины, онлайн-магазины, женщины, товары для ...
# 6  вклад, покупка жилья, госдума, законопроект, и...
# 7  аэрофлот, отмена рейсов, август, закрытые границы
# 8                    значки, сказки, heart of moscow
# 9  собянин, маска, мэр москвы, сергей собянин, на...
#
#                                                 Gold  \
# 0    [ярмарка, современное искусство, гостиный двор]
# 1                        [манеж, кириллица, алфавит]
# 2  [вакцина, коронавирус, сергей собянин, вакцина...
# 3                                [охотка, маросейка]
# 4                                 [суд, ограничения]
# 5                             [исследование, деньги]
# 6             [покупка жилья, госдума, законопроект]
# 7                          [аэрофлот, отмена рейсов]
# 8                  [значки, сказки, heart of moscow]
# 9  [сергей собянин, масочный режим, кофемания, ка...
#
#                                                 RAKE
# 0  [a-s-t-r-agallery, зато онлайн-формат, это год...
# 1  [александр шишкин-хокусать, александр шишкин-х...
# 2  [свой блог, оставить заявка, сайт мэрия, медиц...
# 3  [конец июнь, прошлый неделя, появиться проблем...
# 4  [ресторанный дворик, торговый центр, развлекат...
# 5  [измениться онлайн-рынок, доля интернет-торгов...
# 6  [помочь гражданин, покупка жильё, накапливать ...
# 7  [возобновление авиасообщение, правительство об...
# 8  [герой сказка, продажа ещё, третьяковский гале...
# 9  [стать штрафовать, речь идти, средство защита,...

# %% [markdown]
# #### TextRank

# %%
def textrank_kw():
    kw_textrank = []
    for text in list(corpus.Text):
        kw_per_text = []
        kw_list = keywords.keywords(normalize_text(text), 
                                    language='russian', additional_stopwords=stop, scores=True)
        for l in kw_list:
            kw_per_text.append(l[0])
        kw_textrank.append(kw_per_text)
        
    corpus['TextRank'] = kw_textrank
    return kw_textrank

# %%
kw_textrank = textrank_kw()

# %%
corpus
# Out:
#                                                 Text  \
# 0  С 11 по 13 сентября в Гостином дворе пройдет у...
# 1  ЦВЗ «Манеж» запустил выставочный проект «33 зн...
# 2  Исследовательский центр имени Гамалеи при подд...
# 3  Рыбный ресторан «Охотка» открылся в конце июня...
# 4  Владельцы ТРК «Европолис» — Fort Group — подал...
# 5  Банк «Русский стандарт» изучил, что россияне п...
# 6  В Госдуму внесли законопроект о запуске механи...
# 7  Несмотря на возобновление авиасообщения с авгу...
# 8  Бренд московских сувениров Heart of Moscow вып...
# 9  Мэра Москвы Сергея Собянина не стали штрафоват...
#
#                                     Village_keywords  \
# 0  современное искусство, выставка, ярмарка, сosm...
# 1  выставки, уличное искусство, уличные выставки,...
# 2  коронавирус, вакцинация, вакцина, covid-19, се...
# 3  архитектура, сохранение исторического центра, ...
# 4  бизнес, суд, чиновники, ограничения, торговый ...
# 5  онлайн-шопинг, торговля, ритейл, деньги, интер...
# 6  вклады, покупка жилья, кредиты, ипотека, закон...
# 7  авиасообщение, авиасообщение с турцией, отмена...
# 8  значки, сказки, картины, художники, heart of m...
# 9  кофемания, масочный режим, карантин, штраф, се...
#
#                                          My_keywords  \
# 0  ярмарка, современное искусство, cosmoscow, сен...
# 1  манеж, выставочный проект, 33 знака, кириллица...
# 2  москва, вакцина, коронавирус, сергей собянин, ...
# 3  охотка, маросейка, уничтожение окон, историчес...
# 4  трк Европолис, fort group, суд, смольный, рабо...
# 5  мужчины, онлайн-магазины, женщины, товары для ...
# 6  вклад, покупка жилья, госдума, законопроект, и...
# 7  аэрофлот, отмена рейсов, август, закрытые границы
# 8                    значки, сказки, heart of moscow
# 9  собянин, маска, мэр москвы, сергей собянин, на...
#
#                                                 Gold  \
# 0    [ярмарка, современное искусство, гостиный двор]
# 1                        [манеж, кириллица, алфавит]
# 2  [вакцина, коронавирус, сергей собянин, вакцина...
# 3                                [охотка, маросейка]
# 4                                 [суд, ограничения]
# 5                             [исследование, деньги]
# 6             [покупка жилья, госдума, законопроект]
# 7                          [аэрофлот, отмена рейсов]
# 8                  [значки, сказки, heart of moscow]
# 9  [сергей собянин, масочный режим, кофемания, ка...
#
#                                                 RAKE  \
# 0  [a-s-t-r-agallery, зато онлайн-формат, это год...
# 1  [александр шишкин-хокусать, александр шишкин-х...
# 2  [свой блог, оставить заявка, сайт мэрия, медиц...
# 3  [конец июнь, прошлый неделя, появиться проблем...
# 4  [ресторанный дворик, торговый центр, развлекат...
# 5  [измениться онлайн-рынок, доля интернет-торгов...
# 6  [помочь гражданин, покупка жильё, накапливать ...
# 7  [возобновление авиасообщение, правительство об...
# 8  [герой сказка, продажа ещё, третьяковский гале...
# 9  [стать штрафовать, речь идти, средство защита,...
#
#                                             TextRank
# 0  [год, art, галерея, работа, показать, создать,...
# 1  [манеж, лабиринт, выставочный проект, дизайн, ...
# 2  [вакцина, центр, российский, исследование перв...
# 3  [никто, охотка, проект, окно исторический здан...
# 4  [европолис, fort group, владелец трк, подать, ...
# 5  [большой, онлайн, мужчина, год, интернет, весь...
# 6  [жильё, договор, мочь, должный, банк, кредитны...
# 7  [август, рейс, полёт, который, аэрофлот, дата,...
# 8  [русский, сказка, серия значок, точка, бренд, ...
# 9  [елена андреев, москва, собянин, несколько рес...

# %% [markdown]
# #### TFIDF

# %%
def tfidf_kw():
    norm_text = [normalize_text(text) for text in list(corpus.Text)]
    kw_tfidf = []
    vectorizer = TfidfVectorizer(use_idf=True, norm='l2', stop_words=stop, ngram_range=(1, 3))
    tfidf = vectorizer.fit_transform(norm_text)
    words = np.array(vectorizer.get_feature_names())
    for vec in tfidf:
        index_sorted = np.argsort(vec.toarray()).ravel()[::-1]
        kw_per_text = words[index_sorted][:10].tolist()
        kw_tfidf.append(kw_per_text)
    
    corpus['TFIDF'] = kw_tfidf
    return kw_tfidf

# %%
kw_tfidf = tfidf_kw()

# %%
corpus
# Out:
#                                                 Text  \
# 0  С 11 по 13 сентября в Гостином дворе пройдет у...
# 1  ЦВЗ «Манеж» запустил выставочный проект «33 зн...
# 2  Исследовательский центр имени Гамалеи при подд...
# 3  Рыбный ресторан «Охотка» открылся в конце июня...
# 4  Владельцы ТРК «Европолис» — Fort Group — подал...
# 5  Банк «Русский стандарт» изучил, что россияне п...
# 6  В Госдуму внесли законопроект о запуске механи...
# 7  Несмотря на возобновление авиасообщения с авгу...
# 8  Бренд московских сувениров Heart of Moscow вып...
# 9  Мэра Москвы Сергея Собянина не стали штрафоват...
#
#                                     Village_keywords  \
# 0  современное искусство, выставка, ярмарка, сosm...
# 1  выставки, уличное искусство, уличные выставки,...
# 2  коронавирус, вакцинация, вакцина, covid-19, се...
# 3  архитектура, сохранение исторического центра, ...
# 4  бизнес, суд, чиновники, ограничения, торговый ...
# 5  онлайн-шопинг, торговля, ритейл, деньги, интер...
# 6  вклады, покупка жилья, кредиты, ипотека, закон...
# 7  авиасообщение, авиасообщение с турцией, отмена...
# 8  значки, сказки, картины, художники, heart of m...
# 9  кофемания, масочный режим, карантин, штраф, се...
#
#                                          My_keywords  \
# 0  ярмарка, современное искусство, cosmoscow, сен...
# 1  манеж, выставочный проект, 33 знака, кириллица...
# 2  москва, вакцина, коронавирус, сергей собянин, ...
# 3  охотка, маросейка, уничтожение окон, историчес...
# 4  трк Европолис, fort group, суд, смольный, рабо...
# 5  мужчины, онлайн-магазины, женщины, товары для ...
# 6  вклад, покупка жилья, госдума, законопроект, и...
# 7  аэрофлот, отмена рейсов, август, закрытые границы
# 8                    значки, сказки, heart of moscow
# 9  собянин, маска, мэр москвы, сергей собянин, на...
#
#                                                 Gold  \
# 0    [ярмарка, современное искусство, гостиный двор]
# 1                        [манеж, кириллица, алфавит]
# 2  [вакцина, коронавирус, сергей собянин, вакцина...
# 3                                [охотка, маросейка]
# 4                                 [суд, ограничения]
# 5                             [исследование, деньги]
# 6             [покупка жилья, госдума, законопроект]
# 7                          [аэрофлот, отмена рейсов]
# 8                  [значки, сказки, heart of moscow]
# 9  [сергей собянин, масочный режим, кофемания, ка...
#
#                                                 RAKE  \
# 0  [a-s-t-r-agallery, зато онлайн-формат, это год...
# 1  [александр шишкин-хокусать, александр шишкин-х...
# 2  [свой блог, оставить заявка, сайт мэрия, медиц...
# 3  [конец июнь, прошлый неделя, появиться проблем...
# 4  [ресторанный дворик, торговый центр, развлекат...
# 5  [измениться онлайн-рынок, доля интернет-торгов...
# 6  [помочь гражданин, покупка жильё, накапливать ...
# 7  [возобновление авиасообщение, правительство об...
# 8  [герой сказка, продажа ещё, третьяковский гале...
# 9  [стать штрафовать, речь идти, средство защита,...
#
#                                             TextRank  \
# 0  [год, art, галерея, работа, показать, создать,...
# 1  [манеж, лабиринт, выставочный проект, дизайн, ...
# 2  [вакцина, центр, российский, исследование перв...
# 3  [никто, охотка, проект, окно исторический здан...
# 4  [европолис, fort group, владелец трк, подать, ...
# 5  [большой, онлайн, мужчина, год, интернет, весь...
# 6  [жильё, договор, мочь, должный, банк, кредитны...
# 7  [август, рейс, полёт, который, аэрофлот, дата,...
# 8  [русский, сказка, серия значок, точка, бренд, ...
# 9  [елена андреев, москва, собянин, несколько рес...
#
#                                                TFIDF
# 0  [ярмарка, cosmoscow, галерея, показать, искусс...
# 1  [кириллический, лабиринт, манеж, проект, выста...
# 2  [вакцина, исследование, москвич, гамалея, учас...
# 3  [окно, никто, здание, охотка, договор, проект,...
# 4  [левченко, запрет работа, работа, работать, за...
# 5  [женщина, мужчина, интернет, онлайн, магазин, ...
# 6  [банк, договор, жильё, законопроект, вклад, сб...
# 7  [рейс, билет, полёт, август, аэрофлот, отмена,...
# 8  [значок, сказка, серия, of, heart of moscow, o...
# 9  [собянин, нарушение, выявить нарушение, веранд...

# %% [markdown]
# ### Задание 4.

# %% [markdown]
# Составляем морфологические/синтаксические шаблоны для ключевых слов и фраз

# %%
def extraxt_patterns(gold_kw):
    patterns = []
    for kws in gold_kw:
        for kw in kws:
            splitted_kw = kw.split()
            pos_phrase = []
            for s_kw in splitted_kw:
                if re.search('[a-zA-Z]', s_kw):
                    pos = 'ENG_NAME'
                else:
                    p = m.parse(s_kw)[0]
                    pos = p.tag.POS
                pos_phrase.append(pos)
                
            pos_phrase = ' '.join(pos_phrase)
            if pos_phrase not in patterns:
                patterns.append(pos_phrase)
                
    return patterns

# %%
patterns = extraxt_patterns(gold_kw)

# %%
patterns
# Out:
# ['NOUN', 'ADJF NOUN', 'NOUN NOUN', 'ENG_NAME', 'ENG_NAME ENG_NAME ENG_NAME']

# %% [markdown]
# Выделяем соответствующие им подстроки из корпуса

# %%
def find_patterns_text(patterns):
    all_extracted = []
    for text in list(corpus.Text):
        extracted = []
        sentences = sent_tokenize(text)
        for sent in sentences:
            tokens = nltk.word_tokenize(sent)
            bigrams = list(ngrams(tokens, 2))
            trigrams = list(ngrams(tokens, 3))
            for pattern in patterns:
                splitted_pattern = pattern.split()
                if len(splitted_pattern) == 1:
                    for token in tokens:
                        if re.search('[a-zA-Z]', token):
                            pos = 'ENG_NAME'
                        else:
                            p = m.parse(token)[0]
                            pos = p.tag.POS

                        if (str(pos) == splitted_pattern[0]) and (token not in extracted):
                            extracted.append(token)
                elif len(splitted_pattern) == 2:
                    for bigram in bigrams:
                        if re.search('[a-zA-Z]', bigram[0][0]):
                            pos1 = 'ENG_NAME'
                        else:
                            p1 = m.parse(bigram[0][0])[0]
                            pos1 = p1.tag.POS
                            
                        if re.search('[a-zA-Z]', bigram[1][0]):
                            pos2 = 'ENG_NAME'
                        else:
                            p2 = m.parse(bigram[1][0])[0]
                            pos2 = p2.tag.POS
                            
                        if (str(pos1) == splitted_pattern[0]) and (str(pos2) == splitted_pattern[1]):
                            match = bigram[0][0] + ' ' + bigram[1][0]
                            if match not in extracted:
                                extracted.append(match)
                else:
                    for trigram in trigrams:
                        if re.search('[a-zA-Z]', trigram[0][0]):
                            pos1 = 'ENG_NAME'
                        else:
                            p1 = m.parse(trigram[0][0])[0]
                            pos1 = p1.tag.POS
                            
                        if re.search('[a-zA-Z]', trigram[1][0]):
                            pos2 = 'ENG_NAME'
                        else:
                            p2 = m.parse(trigram[1][0])[0]
                            pos2 = p2.tag.POS
                        
                        if re.search('[a-zA-Z]', trigram[2][0]):
                            pos3 = 'ENG_NAME'
                        else:
                            p3 = m.parse(trigram[2][0])[0]
                            pos3 = p3.tag.POS
                        
                        if (str(pos1) == splitted_pattern[0]) and (str(pos2) == splitted_pattern[1]) \
                            and (str(pos3) == splitted_pattern[2]):
                            match = trigram[0][0] + ' ' + trigram[1][0] + ' ' + trigram[2][0]
                            if match not in extracted:
                                extracted.append(match)
                                
        all_extracted.append(extracted)
    
    corpus['Appropriate_pattern_string'] = all_extracted
    
    return all_extracted

# %%
all_extracted = find_patterns_text(patterns)

# %%
corpus
# Out:
#                                                 Text  \
# 0  С 11 по 13 сентября в Гостином дворе пройдет у...
# 1  ЦВЗ «Манеж» запустил выставочный проект «33 зн...
# 2  Исследовательский центр имени Гамалеи при подд...
# 3  Рыбный ресторан «Охотка» открылся в конце июня...
# 4  Владельцы ТРК «Европолис» — Fort Group — подал...
# 5  Банк «Русский стандарт» изучил, что россияне п...
# 6  В Госдуму внесли законопроект о запуске механи...
# 7  Несмотря на возобновление авиасообщения с авгу...
# 8  Бренд московских сувениров Heart of Moscow вып...
# 9  Мэра Москвы Сергея Собянина не стали штрафоват...
#
#                                     Village_keywords  \
# 0  современное искусство, выставка, ярмарка, сosm...
# 1  выставки, уличное искусство, уличные выставки,...
# 2  коронавирус, вакцинация, вакцина, covid-19, се...
# 3  архитектура, сохранение исторического центра, ...
# 4  бизнес, суд, чиновники, ограничения, торговый ...
# 5  онлайн-шопинг, торговля, ритейл, деньги, интер...
# 6  вклады, покупка жилья, кредиты, ипотека, закон...
# 7  авиасообщение, авиасообщение с турцией, отмена...
# 8  значки, сказки, картины, художники, heart of m...
# 9  кофемания, масочный режим, карантин, штраф, се...
#
#                                          My_keywords  \
# 0  ярмарка, современное искусство, cosmoscow, сен...
# 1  манеж, выставочный проект, 33 знака, кириллица...
# 2  москва, вакцина, коронавирус, сергей собянин, ...
# 3  охотка, маросейка, уничтожение окон, историчес...
# 4  трк Европолис, fort group, суд, смольный, рабо...
# 5  мужчины, онлайн-магазины, женщины, товары для ...
# 6  вклад, покупка жилья, госдума, законопроект, и...
# 7  аэрофлот, отмена рейсов, август, закрытые границы
# 8                    значки, сказки, heart of moscow
# 9  собянин, маска, мэр москвы, сергей собянин, на...
#
#                                                 Gold  \
# 0    [ярмарка, современное искусство, гостиный двор]
# 1                        [манеж, кириллица, алфавит]
# 2  [вакцина, коронавирус, сергей собянин, вакцина...
# 3                                [охотка, маросейка]
# 4                                 [суд, ограничения]
# 5                             [исследование, деньги]
# 6             [покупка жилья, госдума, законопроект]
# 7                          [аэрофлот, отмена рейсов]
# 8                  [значки, сказки, heart of moscow]
# 9  [сергей собянин, масочный режим, кофемания, ка...
#
#                                                 RAKE  \
# 0  [a-s-t-r-agallery, зато онлайн-формат, это год...
# 1  [александр шишкин-хокусать, александр шишкин-х...
# 2  [свой блог, оставить заявка, сайт мэрия, медиц...
# 3  [конец июнь, прошлый неделя, появиться проблем...
# 4  [ресторанный дворик, торговый центр, развлекат...
# 5  [измениться онлайн-рынок, доля интернет-торгов...
# 6  [помочь гражданин, покупка жильё, накапливать ...
# 7  [возобновление авиасообщение, правительство об...
# 8  [герой сказка, продажа ещё, третьяковский гале...
# 9  [стать штрафовать, речь идти, средство защита,...
#
#                                             TextRank  \
# 0  [год, art, галерея, работа, показать, создать,...
# 1  [манеж, лабиринт, выставочный проект, дизайн, ...
# 2  [вакцина, центр, российский, исследование перв...
# 3  [никто, охотка, проект, окно исторический здан...
# 4  [европолис, fort group, владелец трк, подать, ...
# 5  [большой, онлайн, мужчина, год, интернет, весь...
# 6  [жильё, договор, мочь, должный, банк, кредитны...
# 7  [август, рейс, полёт, который, аэрофлот, дата,...
# 8  [русский, сказка, серия значок, точка, бренд, ...
# 9  [елена андреев, москва, собянин, несколько рес...
#
#                                                TFIDF  \
# 0  [ярмарка, cosmoscow, галерея, показать, искусс...
# 1  [кириллический, лабиринт, манеж, проект, выста...
# 2  [вакцина, исследование, москвич, гамалея, учас...
# 3  [окно, никто, здание, охотка, договор, проект,...
# 4  [левченко, запрет работа, работа, работать, за...
# 5  [женщина, мужчина, интернет, онлайн, магазин, ...
# 6  [банк, договор, жильё, законопроект, вклад, сб...
# 7  [рейс, билет, полёт, август, аэрофлот, отмена,...
# 8  [значок, сказка, серия, of, heart of moscow, o...
# 9  [собянин, нарушение, выявить нарушение, веранд...
#
#                           Appropriate_pattern_string
# 0  [сентября, дворе, ярмарка, искусства, Cosmosco...
# 1  [Манеж, проект, знака, алфавиту, Выставка, инс...
# 2  [центр, имени, Гамалеи, поддержке, фонда, инве...
# 3  [ресторан, Охотка, конце, июня, Маросейке, ули...
# 4  [Владельцы, Европолис, суд, Фонтанке, партнер,...
# 5  [Банк, стандарт, россияне, интернет-магазинах,...
# 6  [Госдуму, законопроект, запуске, механизма, си...
# 7  [возобновление, авиасообщения, августа, России...
# 8  [Бренд, сувениров, серию, значков, героями, ск...
# 9  [Мэра, Москвы, Сергея, Собянина, нарушение, ре...

# %% [markdown]
# Применяем эти фильтры к спискам ключевых слов

# %%
def filter_kw(keywords, patterns):
    all_filtered_kws = []
    for kws in keywords:
        filtered_kws = []
        for kw in kws:
            for pattern in patterns:
                if len(kw.split(' ')) == len(pattern.split(' ')):
                    kw_pos = []
                    for i in range(len(kw.split(' '))):
                        if re.search('[a-zA-Z]', kw.split(' ')[i]):
                            pos = 'ENG_NAME'
                        else:
                            p = m.parse(kw.split(' ')[i])[0]
                            pos = p.tag.POS
                            
                        kw_pos.append(str(pos))
                    
                if ' '.join(kw_pos) == pattern:
                    filtered_kws.append(kw)
                        
        all_filtered_kws.append(filtered_kws)
        
    return all_filtered_kws

# %%
filtered_rake = filter_kw(kw_rake, patterns)
corpus['filtered_RAKE'] = filtered_rake

# %%
filtered_textrank = filter_kw(kw_textrank, patterns)
corpus['filtered_TextRank'] = filtered_textrank

# %%
filtered_tfidf = filter_kw(kw_tfidf, patterns)
corpus['filtered_TFIDF'] = filtered_tfidf

# %%
corpus
# Out:
#                                                 Text  \
# 0  С 11 по 13 сентября в Гостином дворе пройдет у...
# 1  ЦВЗ «Манеж» запустил выставочный проект «33 зн...
# 2  Исследовательский центр имени Гамалеи при подд...
# 3  Рыбный ресторан «Охотка» открылся в конце июня...
# 4  Владельцы ТРК «Европолис» — Fort Group — подал...
# 5  Банк «Русский стандарт» изучил, что россияне п...
# 6  В Госдуму внесли законопроект о запуске механи...
# 7  Несмотря на возобновление авиасообщения с авгу...
# 8  Бренд московских сувениров Heart of Moscow вып...
# 9  Мэра Москвы Сергея Собянина не стали штрафоват...
#
#                                     Village_keywords  \
# 0  современное искусство, выставка, ярмарка, сosm...
# 1  выставки, уличное искусство, уличные выставки,...
# 2  коронавирус, вакцинация, вакцина, covid-19, се...
# 3  архитектура, сохранение исторического центра, ...
# 4  бизнес, суд, чиновники, ограничения, торговый ...
# 5  онлайн-шопинг, торговля, ритейл, деньги, интер...
# 6  вклады, покупка жилья, кредиты, ипотека, закон...
# 7  авиасообщение, авиасообщение с турцией, отмена...
# 8  значки, сказки, картины, художники, heart of m...
# 9  кофемания, масочный режим, карантин, штраф, се...
#
#                                          My_keywords  \
# 0  ярмарка, современное искусство, cosmoscow, сен...
# 1  манеж, выставочный проект, 33 знака, кириллица...
# 2  москва, вакцина, коронавирус, сергей собянин, ...
# 3  охотка, маросейка, уничтожение окон, историчес...
# 4  трк Европолис, fort group, суд, смольный, рабо...
# 5  мужчины, онлайн-магазины, женщины, товары для ...
# 6  вклад, покупка жилья, госдума, законопроект, и...
# 7  аэрофлот, отмена рейсов, август, закрытые границы
# 8                    значки, сказки, heart of moscow
# 9  собянин, маска, мэр москвы, сергей собянин, на...
#
#                                                 Gold  \
# 0    [ярмарка, современное искусство, гостиный двор]
# 1                        [манеж, кириллица, алфавит]
# 2  [вакцина, коронавирус, сергей собянин, вакцина...
# 3                                [охотка, маросейка]
# 4                                 [суд, ограничения]
# 5                             [исследование, деньги]
# 6             [покупка жилья, госдума, законопроект]
# 7                          [аэрофлот, отмена рейсов]
# 8                  [значки, сказки, heart of moscow]
# 9  [сергей собянин, масочный режим, кофемания, ка...
#
#                                                 RAKE  \
# 0  [a-s-t-r-agallery, зато онлайн-формат, это год...
# 1  [александр шишкин-хокусать, александр шишкин-х...
# 2  [свой блог, оставить заявка, сайт мэрия, медиц...
# 3  [конец июнь, прошлый неделя, появиться проблем...
# 4  [ресторанный дворик, торговый центр, развлекат...
# 5  [измениться онлайн-рынок, доля интернет-торгов...
# 6  [помочь гражданин, покупка жильё, накапливать ...
# 7  [возобновление авиасообщение, правительство об...
# 8  [герой сказка, продажа ещё, третьяковский гале...
# 9  [стать штрафовать, речь идти, средство защита,...
#
#                                             TextRank  \
# 0  [год, art, галерея, работа, показать, создать,...
# 1  [манеж, лабиринт, выставочный проект, дизайн, ...
# 2  [вакцина, центр, российский, исследование перв...
# 3  [никто, охотка, проект, окно исторический здан...
# 4  [европолис, fort group, владелец трк, подать, ...
# 5  [большой, онлайн, мужчина, год, интернет, весь...
# 6  [жильё, договор, мочь, должный, банк, кредитны...
# 7  [август, рейс, полёт, который, аэрофлот, дата,...
# 8  [русский, сказка, серия значок, точка, бренд, ...
# 9  [елена андреев, москва, собянин, несколько рес...
#
#                                                TFIDF  \
# 0  [ярмарка, cosmoscow, галерея, показать, искусс...
# 1  [кириллический, лабиринт, манеж, проект, выста...
# 2  [вакцина, исследование, москвич, гамалея, учас...
# 3  [окно, никто, здание, охотка, договор, проект,...
# 4  [левченко, запрет работа, работа, работать, за...
# 5  [женщина, мужчина, интернет, онлайн, магазин, ...
# 6  [банк, договор, жильё, законопроект, вклад, сб...
# 7  [рейс, билет, полёт, август, аэрофлот, отмена,...
# 8  [значок, сказка, серия, of, heart of moscow, o...
# 9  [собянин, нарушение, выявить нарушение, веранд...
#
#                           Appropriate_pattern_string  \
# 0  [сентября, дворе, ярмарка, искусства, Cosmosco...
# 1  [Манеж, проект, знака, алфавиту, Выставка, инс...
# 2  [центр, имени, Гамалеи, поддержке, фонда, инве...
# 3  [ресторан, Охотка, конце, июня, Маросейке, ули...
# 4  [Владельцы, Европолис, суд, Фонтанке, партнер,...
# 5  [Банк, стандарт, россияне, интернет-магазинах,...
# 6  [Госдуму, законопроект, запуске, механизма, си...
# 7  [возобновление, авиасообщения, августа, России...
# 8  [Бренд, сувениров, серию, значков, героями, ск...
# 9  [Мэра, Москвы, Сергея, Собянина, нарушение, ре...
#
#                                        filtered_RAKE  \
# 0  [a-s-t-r-agallery, импровизированный галерея, ...
# 1  [юрий гордон, митя харшак, качество куратор, с...
# 2  [свой блог, свой блог, сайт мэрия, медицинский...
# 3  [конец июнь, прошлый неделя, местный активист,...
# 4  [ресторанный дворик, торговый центр, развлекат...
# 5  [доля интернет-торговля, интернет-магазин, онл...
# 6  [покупка жильё, срок договор, приобретение жил...
# 7  [возобновление авиасообщение, возобновление ав...
# 8  [герой сказка, третьяковский галерея, дизайн к...
# 9  [стать штрафовать, средство защита, уполномоче...
#
#                                    filtered_TextRank  \
# 0  [год, art, галерея, работа, сад, конкурс, янде...
# 1  [манеж, лабиринт, выставочный проект, выставоч...
# 2  [вакцина, центр, участник, человек, москвич, м...
# 3  [охотка, проект, окно исторический здание, дог...
# 4  [европолис, fort group, ресторан, ресторанный ...
# 5  [мужчина, год, интернет, рост, рубль, покупка,...
# 6  [жильё, договор, мочь, банк, автор, вклад, про...
# 7  [август, рейс, полёт, аэрофлот, дата, стоимост...
# 8  [сказка, серия значок, серия значок, точка, бр...
# 9  [елена андреев, елена андреев, москва, собянин...
#
#                                       filtered_TFIDF
# 0  [ярмарка, cosmoscow, галерея, искусство, совре...
# 1  [лабиринт, манеж, проект, арт объект, буква, а...
# 2  [вакцина, исследование, москвич, гамалея, учас...
# 3  [окно, здание, охотка, договор, проект, догово...
# 4  [левченко, запрет работа, запрет работа, работ...
# 5  [женщина, мужчина, интернет, магазин, триллион...
# 6  [банк, договор, жильё, законопроект, вклад, сб...
# 7  [рейс, билет, полёт, август, аэрофлот, отмена,...
# 8  [значок, сказка, серия, of, heart of moscow, h...
# 9  [собянин, нарушение, выявить нарушение, веранд...

# %% [markdown]
# ### Задание 5.

# %% [markdown]
# Оцениваем точность, полноту, F-меру выбранных методов относительно эталона: с учётом морфосинтаксических шаблонов и без них

# %%
norm_gold = [[normalize_text(kw) for kw in kws] for kws in list(corpus.Gold)]

# %%
corpus['normalized_gold'] = norm_gold

# %%
corpus
# Out:
#                                                 Text  \
# 0  С 11 по 13 сентября в Гостином дворе пройдет у...
# 1  ЦВЗ «Манеж» запустил выставочный проект «33 зн...
# 2  Исследовательский центр имени Гамалеи при подд...
# 3  Рыбный ресторан «Охотка» открылся в конце июня...
# 4  Владельцы ТРК «Европолис» — Fort Group — подал...
# 5  Банк «Русский стандарт» изучил, что россияне п...
# 6  В Госдуму внесли законопроект о запуске механи...
# 7  Несмотря на возобновление авиасообщения с авгу...
# 8  Бренд московских сувениров Heart of Moscow вып...
# 9  Мэра Москвы Сергея Собянина не стали штрафоват...
#
#                                     Village_keywords  \
# 0  современное искусство, выставка, ярмарка, сosm...
# 1  выставки, уличное искусство, уличные выставки,...
# 2  коронавирус, вакцинация, вакцина, covid-19, се...
# 3  архитектура, сохранение исторического центра, ...
# 4  бизнес, суд, чиновники, ограничения, торговый ...
# 5  онлайн-шопинг, торговля, ритейл, деньги, интер...
# 6  вклады, покупка жилья, кредиты, ипотека, закон...
# 7  авиасообщение, авиасообщение с турцией, отмена...
# 8  значки, сказки, картины, художники, heart of m...
# 9  кофемания, масочный режим, карантин, штраф, се...
#
#                                          My_keywords  \
# 0  ярмарка, современное искусство, cosmoscow, сен...
# 1  манеж, выставочный проект, 33 знака, кириллица...
# 2  москва, вакцина, коронавирус, сергей собянин, ...
# 3  охотка, маросейка, уничтожение окон, историчес...
# 4  трк Европолис, fort group, суд, смольный, рабо...
# 5  мужчины, онлайн-магазины, женщины, товары для ...
# 6  вклад, покупка жилья, госдума, законопроект, и...
# 7  аэрофлот, отмена рейсов, август, закрытые границы
# 8                    значки, сказки, heart of moscow
# 9  собянин, маска, мэр москвы, сергей собянин, на...
#
#                                                 Gold  \
# 0    [ярмарка, современное искусство, гостиный двор]
# 1                        [манеж, кириллица, алфавит]
# 2  [вакцина, коронавирус, сергей собянин, вакцина...
# 3                                [охотка, маросейка]
# 4                                 [суд, ограничения]
# 5                             [исследование, деньги]
# 6             [покупка жилья, госдума, законопроект]
# 7                          [аэрофлот, отмена рейсов]
# 8                  [значки, сказки, heart of moscow]
# 9  [сергей собянин, масочный режим, кофемания, ка...
#
#                                                 RAKE  \
# 0  [a-s-t-r-agallery, зато онлайн-формат, это год...
# 1  [александр шишкин-хокусать, александр шишкин-х...
# 2  [свой блог, оставить заявка, сайт мэрия, медиц...
# 3  [конец июнь, прошлый неделя, появиться проблем...
# 4  [ресторанный дворик, торговый центр, развлекат...
# 5  [измениться онлайн-рынок, доля интернет-торгов...
# 6  [помочь гражданин, покупка жильё, накапливать ...
# 7  [возобновление авиасообщение, правительство об...
# 8  [герой сказка, продажа ещё, третьяковский гале...
# 9  [стать штрафовать, речь идти, средство защита,...
#
#                                             TextRank  \
# 0  [год, art, галерея, работа, показать, создать,...
# 1  [манеж, лабиринт, выставочный проект, дизайн, ...
# 2  [вакцина, центр, российский, исследование перв...
# 3  [никто, охотка, проект, окно исторический здан...
# 4  [европолис, fort group, владелец трк, подать, ...
# 5  [большой, онлайн, мужчина, год, интернет, весь...
# 6  [жильё, договор, мочь, должный, банк, кредитны...
# 7  [август, рейс, полёт, который, аэрофлот, дата,...
# 8  [русский, сказка, серия значок, точка, бренд, ...
# 9  [елена андреев, москва, собянин, несколько рес...
#
#                                                TFIDF  \
# 0  [ярмарка, cosmoscow, галерея, показать, искусс...
# 1  [кириллический, лабиринт, манеж, проект, выста...
# 2  [вакцина, исследование, москвич, гамалея, учас...
# 3  [окно, никто, здание, охотка, договор, проект,...
# 4  [левченко, запрет работа, работа, работать, за...
# 5  [женщина, мужчина, интернет, онлайн, магазин, ...
# 6  [банк, договор, жильё, законопроект, вклад, сб...
# 7  [рейс, билет, полёт, август, аэрофлот, отмена,...
# 8  [значок, сказка, серия, of, heart of moscow, o...
# 9  [собянин, нарушение, выявить нарушение, веранд...
#
#                           Appropriate_pattern_string  \
# 0  [сентября, дворе, ярмарка, искусства, Cosmosco...
# 1  [Манеж, проект, знака, алфавиту, Выставка, инс...
# 2  [центр, имени, Гамалеи, поддержке, фонда, инве...
# 3  [ресторан, Охотка, конце, июня, Маросейке, ули...
# 4  [Владельцы, Европолис, суд, Фонтанке, партнер,...
# 5  [Банк, стандарт, россияне, интернет-магазинах,...
# 6  [Госдуму, законопроект, запуске, механизма, си...
# 7  [возобновление, авиасообщения, августа, России...
# 8  [Бренд, сувениров, серию, значков, героями, ск...
# 9  [Мэра, Москвы, Сергея, Собянина, нарушение, ре...
#
#                                        filtered_RAKE  \
# 0  [a-s-t-r-agallery, импровизированный галерея, ...
# 1  [юрий гордон, митя харшак, качество куратор, с...
# 2  [свой блог, свой блог, сайт мэрия, медицинский...
# 3  [конец июнь, прошлый неделя, местный активист,...
# 4  [ресторанный дворик, торговый центр, развлекат...
# 5  [доля интернет-торговля, интернет-магазин, онл...
# 6  [покупка жильё, срок договор, приобретение жил...
# 7  [возобновление авиасообщение, возобновление ав...
# 8  [герой сказка, третьяковский галерея, дизайн к...
# 9  [стать штрафовать, средство защита, уполномоче...
#
#                                    filtered_TextRank  \
# 0  [год, art, галерея, работа, сад, конкурс, янде...
# 1  [манеж, лабиринт, выставочный проект, выставоч...
# 2  [вакцина, центр, участник, человек, москвич, м...
# 3  [охотка, проект, окно исторический здание, дог...
# 4  [европолис, fort group, ресторан, ресторанный ...
# 5  [мужчина, год, интернет, рост, рубль, покупка,...
# 6  [жильё, договор, мочь, банк, автор, вклад, про...
# 7  [август, рейс, полёт, аэрофлот, дата, стоимост...
# 8  [сказка, серия значок, серия значок, точка, бр...
# 9  [елена андреев, елена андреев, москва, собянин...
#
#                                       filtered_TFIDF  \
# 0  [ярмарка, cosmoscow, галерея, искусство, совре...
# 1  [лабиринт, манеж, проект, арт объект, буква, а...
# 2  [вакцина, исследование, москвич, гамалея, учас...
# 3  [окно, здание, охотка, договор, проект, догово...
# 4  [левченко, запрет работа, запрет работа, работ...
# 5  [женщина, мужчина, интернет, магазин, триллион...
# 6  [банк, договор, жильё, законопроект, вклад, сб...
# 7  [рейс, билет, полёт, август, аэрофлот, отмена,...
# 8  [значок, сказка, серия, of, heart of moscow, h...
# 9  [собянин, нарушение, выявить нарушение, веранд...
#
#                                      normalized_gold
# 0    [ярмарка, современный искусство, гостиный двор]
# 1                        [манеж, кириллица, алфавит]
# 2  [вакцина, коронавирус, сергей собянин, вакцина...
# 3                                [охотка, маросейка]
# 4                                 [суд, ограничение]
# 5                             [исследование, деньга]
# 6             [покупка жильё, госдума, законопроект]
# 7                            [аэрофлот, отмена рейс]
# 8                  [значок, сказка, heart of moscow]
# 9  [сергей собянин, масочный режим, кофемания, ка...

# %%
def metrics(keywords, gold_kw):
    all_precision = 0
    all_recall = 0
    all_f1 = 0
    for i in range(len(keywords)):
        tp = 0
        fp = 0 
        fn = 0
        for kw in keywords[i]:
            if kw in gold_kw[i]:
                tp += 1
            else:
                fp += 1
    
        for kw in gold_kw[i]:
            if kw not in keywords[i]:
                fn += 1

        precision = tp / (tp + fp)
        all_precision += precision
        recall = tp / (tp + fn)
        all_recall += recall
        if (precision == 0) or (recall == 0):
            f1 = 0
        else:
            f1 = 2 * (precision * recall) / (precision + recall)
        
        all_f1 += f1
        
    return all_precision/len(keywords), all_recall/len(keywords), all_f1/len(keywords)

# %%
print("RAKE")
precision, recall, f1 = metrics(kw_rake, norm_gold)
print("precision: ", precision)
print("recall: ", recall)
print("f1: ", f1)
# Out:
# RAKE
# precision:  0.02678250108397167
# recall:  0.30166666666666664
# f1:  0.04802481634728286

# %%
print("TextRank")
precision, recall, f1 = metrics(kw_textrank, norm_gold)
print("precision: ", precision)
print("recall: ", recall)
print("f1: ", f1)
# Out:
# TextRank
# precision:  0.026185721294416948
# recall:  0.22666666666666666
# f1:  0.045537599655246716

# %%
print("TFIDF")
precision, recall, f1 = metrics(kw_tfidf, norm_gold)
print("precision: ", precision)
print("recall: ", recall)
print("f1: ", f1)
# Out:
# TFIDF
# precision:  0.13
# recall:  0.44333333333333336
# f1:  0.19769230769230767

# %%
print("Filtered RAKE")
precision, recall, f1 = metrics(filtered_rake, norm_gold)
print("precision: ", precision)
print("recall: ", recall)
print("f1: ", f1)
# Out:
# Filtered RAKE
# precision:  0.05177225768356122
# recall:  0.30166666666666664
# f1:  0.08481476594684143

# %%
print("Filtered TextRank")
precision, recall, f1 = metrics(filtered_textrank, norm_gold)
print("precision: ", precision)
print("recall: ", recall)
print("f1: ", f1)
# Out:
# Filtered TextRank
# precision:  0.039186335403726714
# recall:  0.22666666666666666
# f1:  0.06541624639450726

# %%
print("Filtered TextRank")
precision, recall, f1 = metrics(filtered_tfidf, norm_gold)
print("precision: ", precision)
print("recall: ", recall)
print("f1: ", f1)
# Out:
# Filtered TextRank
# precision:  0.17150793650793653
# recall:  0.45166666666666666
# f1:  0.24398379398379402

# %% [markdown]
# ### Задание 6.

# %% [markdown]
# Ошибки автоматического выделения ключевых слов:
# * Среди нефильтрованных автоматически выделенных слов встречаются глаголы
# * Среди нефильтрованных автоматически выделенных слов встречаются числа. Когда встречаются число + существительное, то это нормально, под такой шаблон часто попадают даты, но когда встречается просто число, то это уже не информативно
# * Некоторые знаки препинания (напр. '»'), не выбрасываются и входят в список стоп слов
# * Несмотря на то, что мы убрали стоп-слова с помощью нлтк, среди автоматически выделенных слов все равно встречаются некоторые предлоги и союзы
# * В текстранке часто встречаются прилагательные по отдельности, что тоже не несет особого смысла

# %% [markdown]
#  Методы решения этих проблем:
#  * Проблему с глаголами, числами и прилагательными как раз решают морфосинтаксические шаблоны
#  * Проблему со знаками препинания можно решить пост-очисткой от пунктуации
#  * Проблему со стоп-словами можно решить ручным расширением списка стоп-слов
